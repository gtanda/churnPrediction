# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('customer_data.csv')
df.columns = [col.lower() for col in df.columns]
df.columns = df.columns.str.replace(' ', '_')
df.drop(columns=['customerid', 'count'], axis = 1, inplace=True)

# %%
df.isna().sum()
# Out:
# country                 0
# state                   0
# city                    0
# zip_code                0
# lat_long                0
# latitude                0
# longitude               0
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# tenure_months           0
# phone_service           0
# multiple_lines          0
# internet_service        0
# online_security         0
# online_backup           0
# device_protection       0
# tech_support            0
# streaming_tv            0
# streaming_movies        0
# contract                0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges           0
# churn_label             0
# churn_value             0
# churn_score             0
# cltv                    0
# churn_reason         5174
# dtype: int64

# %%
y = df['churn_value']
df.drop(columns=['churn_value', 'churn_label', 'churn_score', 'cltv', 'churn_reason'], inplace=True)
df.drop(columns=['country', 'state', 'city', 'zip_code', 'lat_long', 'latitude', 'longitude'], inplace=True)
X = df.loc[:]

# %%
oe = OrdinalEncoder()
oe.fit_transform(X)
# Out:
# array([[1.000e+00, 0.000e+00, 0.000e+00, ..., 3.000e+00, 4.360e+02,
#         1.570e+02],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 2.000e+00, 7.290e+02,
#         9.250e+02],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 2.000e+00, 1.274e+03,
#         6.104e+03],
#        ...,
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 1.000e+00, 1.340e+03,
#         5.698e+03],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 2.000e+00, 1.370e+02,
#         2.994e+03],
#        [1.000e+00, 0.000e+00, 0.000e+00, ..., 0.000e+00, 1.388e+03,
#         5.407e+03]])

# %%
for col in X.columns:
    if X.columns.dtype == 'object':
        X[col] = oe.fit_transform(X[[col]])

# %%
plt.figure(figsize=(20,20))
cor = X.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
model_tree = DecisionTreeRegressor()
model_tree.fit(X_train, y_train)
importance_tree = model_tree.feature_importances_
for i, v in enumerate(importance_tree):
    print('Feature: %0d, Score: %.5f' %(i,v))
# Out:
# Feature: 0, Score: 0.02268
# Feature: 1, Score: 0.02058
# Feature: 2, Score: 0.01782
# Feature: 3, Score: 0.03355
# Feature: 4, Score: 0.12175
# Feature: 5, Score: 0.00488
# Feature: 6, Score: 0.01771
# Feature: 7, Score: 0.01299
# Feature: 8, Score: 0.04483
# Feature: 9, Score: 0.01829
# Feature: 10, Score: 0.01384
# Feature: 11, Score: 0.01542
# Feature: 12, Score: 0.00742
# Feature: 13, Score: 0.01031
# Feature: 14, Score: 0.16794
# Feature: 15, Score: 0.01549
# Feature: 16, Score: 0.03943
# Feature: 17, Score: 0.21852
# Feature: 18, Score: 0.19655

# %%
values = ([x for x in range(len(importance_tree))], importance_tree)
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.bar(values[0], values[1], 0.7)
ax.set_ylabel('Feature Importance %')
ax.set_title('Feature Importance')
ax.set_xlabel('Feature #')
ax.set_xticks(range(len(values[1])))
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7341935483870968

# %%
cols_to_drop = []
for idx, val in enumerate(importance_tree):
    if val < 0.027 or val <= 0:
        cols_to_drop.append(X.columns[idx - 1])

# %%
for col in cols_to_drop:
    X.drop(columns=col, inplace=True)

# %%
model_tree = DecisionTreeRegressor()
model_tree.fit(X, y)
importance_tree = model_tree.feature_importances_
for i, v in enumerate(importance_tree):
    print('Feature: %0d, Score: %.5f' %(i,v))
# Out:
# Feature: 0, Score: 0.05715
# Feature: 1, Score: 0.07014
# Feature: 2, Score: 0.06842
# Feature: 3, Score: 0.03002
# Feature: 4, Score: 0.02808
# Feature: 5, Score: 0.08653
# Feature: 6, Score: 0.65966

# %%
values = ([x for x in range(len(importance_tree))], importance_tree)
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.bar(values[0], values[1], 0.7)
ax.set_ylabel('Feature Importance %')
ax.set_title('Feature Importance')
ax.set_xlabel('Feature #')
ax.set_xticks(range(len(values[1])))
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7217490062464509

# %%
X.columns
# Out:
# Index(['partner', 'dependents', 'internet_service', 'streaming_movies',
#        'paperless_billing', 'payment_method', 'monthly_charges'],
#       dtype='object')
